# %%
exec(open("inc_notebook.py").read())
import logging, sys, math,os
from datetime import datetime
exec(open("classifiers/initKeras.py").read())

# %matplotlib inline
dataStatsDate = datetime(2019, 11, 24)

trainClassCache = 10
validationClassCache = 0
trainBatchesPerEpoch = 10000
validationBatchesPerEpoch = 2000
batch_size = 16

exec(open("classifiers/incDoodleClassifier.py").read())
# Out:
# current working dirF:\myProjects\tfKeras\UCSC\Opensource\DoodleForPicStory
# Using TensorFlow backend.
# WARNING:root:Limiting GPU to 0.8. Increase it in initKeras.py. Next is available GPUs
# WARNING:root:['/job:localhost/replica:0/task:0/device:GPU:0']
# WARNING:root:LivePlotKeras loaded

# %%
model = classifierFactory.create(
    template = 'BasicBN',
    outputClasses = dataStats.stats['countClasses'],
    inputShape = (28, 28, 1)
)

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 28, 28, 1)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 24, 24, 64)        1664
# _________________________________________________________________
# re_lu_1 (ReLU)               (None, 24, 24, 64)        0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 24, 24, 64)        256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 12, 12, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 8, 8, 64)          102464
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 8, 8, 64)          256
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 40)                41000
# _________________________________________________________________
# re_lu_2 (ReLU)               (None, 40)                0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 40)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 4)                 164
# =================================================================
# Total params: 145,804
# Trainable params: 145,548
# Non-trainable params: 256
# _________________________________________________________________

# %%
histories = []
snapshots = 20
startEpoch = 0
epochPerSnapshot = 50
steps_per_epoch = trainBatchesPerEpoch
validation_steps = validationBatchesPerEpoch

for i in range(snapshots):
    
    history = model.fit_generator( 
                        generator=trainGenerator,
                        validation_data=validationGenerator,
                        use_multiprocessing=False, 
                        workers=3, 
                        initial_epoch = startEpoch,
                        epochs=epochPerSnapshot,
                        max_q_size = 10,
                        steps_per_epoch = steps_per_epoch,
                        validation_steps = validation_steps,
                        callbacks = [livePlotKeras]
                       )
    classifierIO.save(model, model.name + '-ss-' + str(i))
    pass
# Out:
# D:\ProgramData\Anaconda3\envs\tf\lib\site-packages\ipykernel_launcher.py:20: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(generator=<dataProce..., validation_data=<dataProce..., use_multiprocessing=False, workers=3, initial_epoch=0, epochs=50, steps_per_epoch=10000, validation_steps=2000, callbacks=[<library...., max_queue_size=10)`
# Epoch 1/50
# Searching data for alarm_clock
# Searching data for alarm_clock
# Searching data for alarm_clock
# Searching data for alarm_clock
# Searching data for alarm_clock
# Searching data for alarm_clock
# Saving alarm_clock in cache
# Searching data for baseball_bat
# Searching data for baseball_batSearching data for baseball_batSearching data for baseball_bat
#
# Searching data for baseball_bat
#
# Searching data for baseball_bat
# Saving baseball_bat in cache
# Searching data for bicycleSearching data for bicycleSearching data for bicycle
#
#
# Searching data for bicycle
# Searching data for bicycle
# Searching data for bicycle
# Saving bicycle in cache
# Searching data for alarm_clock
# Found alarm_clock in cache
# Searching data for alarm_clockSearching data for alarm_clock
#
# Found alarm_clock in cache
# Searching data for alarm_clock
# Found alarm_clock in cache
# Searching data for alarm_clock
# Searching data for baseball_bat
# Found baseball_bat in cache
# Searching data for baseball_bat
# Found baseball_bat in cache
# Searching data for bicycleSearching data for alarm_clock
# Searching data for bicycle
# Found bicycle in cache
#
# Found bicycle in cache
# Searching data for alarm_clock
# Found alarm_clock in cache
# Searching data for baseball_batSearching data for alarm_clock
# Found baseball_bat in cache
#
# Found alarm_clock in cache
# Searching data for baseball_batSearching data for bicycle
# Found baseball_bat in cache
#
# Found bicycle in cache
# Searching data for baseball_bat
# Found baseball_bat in cache
# Searching data for bicycle
# Found bicycle in cache
# Searching data for alarm_clock
# Found alarm_clock in cache
# Searching data for bicycle
# Found bicycle in cache
# Searching data for alarm_clock
# Found alarm_clock in cache
# Searching data for baseball_bat
# Found baseball_bat in cache
# Searching data for alarm_clockSearching data for bicycle
# Found alarm_clock in cache
# Searching data for baseball_bat
# Found baseball_bat in cache
#
# Found bicycle in cache
# Searching data for baseball_bat
# Found baseball_bat in cache
# Searching data for alarm_clock
# Found alarm_clock in cache
# Searching data for bicycleSearching data for bicycle
# Found bicycle in cache
#
# Found bicycle in cache
# Searching data for baseball_bat
# Found baseball_bat in cache
# Searching data for bicycle
# Found bicycle in cache
# Searching data for baseball_batSearching data for baseball_bat
#
# Searching data for baseball_bat
# Searching data for bicycle
# Searching data for bicycleSearching data for bicycle
#
# Searching data for alarm_clock
# Searching data for alarm_clock
# Searching data for alarm_clock
# Searching data for baseball_bat
# Searching data for baseball_bat
# Searching data for baseball_bat
# Searching data for bicycleSearching data for bicycle
# Searching data for bicycle
#
# Searching data for alarm_clock
# Searching data for alarm_clock
# Searching data for baseball_bat
# Searching data for baseball_bat
# Searching data for bicycle
# Searching data for bicycle
#     1/10000 [..............................] - ETA: 6:37:55 - loss: 1.7205 - categorical_accuracy: 0.3750Searching data for alarm_clock
# Found alarm_clock in cache
# Searching data for baseball_bat
# Found baseball_bat in cache
# Searching data for bicycle
# Found bicycle in cache
# Searching data for alarm_clock
# Found alarm_clock in cache
# Searching data for baseball_bat
# Found baseball_bat in cache
# Searching data for bicycle
# Found bicycle in cache
# Searching data for alarm_clock
# Found alarm_clock in cache
# Searching data for baseball_bat
# Found baseball_bat in cache
# Searching data for bicycle
# Found bicycle in cache
# Searching data for alarm_clock
# Found alarm_clock in cache
# Searching data for The_Eiffel_Tower
# Searching data for alarm_clock
# Found alarm_clock in cache
# Searching data for baseball_bat
# Found baseball_bat in cache
# Searching data for bicycle
# Found bicycle in cache
# Searching data for alarm_clock
# Found alarm_clock in cache
# Searching data for baseball_bat
# Found baseball_bat in cache
# Searching data for bicycle
# Found bicycle in cache
# Searching data for alarm_clock
# Found alarm_clock in cache
# Searching data for baseball_bat
# Found baseball_bat in cache
# Searching data for bicycle
# Found bicycle in cache
#     8/10000 [..............................] - ETA: 50:49 - loss: 0.7810 - categorical_accuracy: 0.7188  Searching data for alarm_clock
# Found alarm_clock in cache
# Searching data for baseball_bat
# Found baseball_bat in cache
# Searching data for bicycle
# Found bicycle in cache
# Searching data for alarm_clock
# Found alarm_clock in cache
# Searching data for baseball_bat
# Found baseball_bat in cache
# Searching data for bicycle
# Found bicycle in cache
# Searching data for alarm_clock
# Found alarm_clock in cache
# Searching data for baseball_bat
# Found baseball_bat in cache
# Searching data for bicycle
# Found bicycle in cache
# Searching data for alarm_clock
# Found alarm_clock in cache
# Searching data for baseball_bat
# Found baseball_bat in cache
# Searching data for alarm_clock
# Found alarm_clock in cache
# Saving The_Eiffel_Tower in cache
# Searching data for The_Eiffel_Tower
# Found The_Eiffel_Tower in cache
# Searching data for alarm_clock
# Found alarm_clock in cache
# Searching data for baseball_bat
# Found baseball_bat in cache
# Searching data for bicycle
# Found bicycle in cache
# Searching data for alarm_clock
# Found alarm_clock in cache
# Searching data for baseball_bat
# Found baseball_bat in cache
# Searching data for bicycle
# Found bicycle in cache
# Searching data for alarm_clock
# Found alarm_clock in cache
# Searching data for baseball_bat
# Found baseball_bat in cache
# Searching data for bicycle
# Found bicycle in cache
#    15/10000 [..............................] - ETA: 27:42 - loss: 0.6177 - categorical_accuracy: 0.7958Searching data for alarm_clock
# Found alarm_clock in cache
# Searching data for baseball_bat
# Found baseball_bat in cache
# Searching data for bicycle
# Found bicycle in cache
# Searching data for alarm_clock
# Found alarm_clock in cache
# Searching data for baseball_bat
# Found baseball_bat in cache
# Searching data for bicycle
# Found bicycle in cache
# Searching data for alarm_clock
# Found alarm_clock in cache
# Searching data for baseball_bat
# Found baseball_bat in cache
# Searching data for bicycle
# Found bicycle in cache
# Searching data for alarm_clock
# Found alarm_clock in cache
# Searching data for baseball_bat
# Found baseball_bat in cache
# Searching data for bicycle
# Found bicycle in cache
# Searching data for alarm_clock
# Found alarm_clock in cache
# Searching data for baseball_bat
# Found baseball_bat in cache
# Searching data for bicycle
# Found bicycle in cache
# Searching data for alarm_clock
# Found alarm_clock in cache
# Searching data for baseball_bat
# Found baseball_bat in cache
# Searching data for bicycle
# Found bicycle in cache
# Searching data for alarm_clock
# Found alarm_clock in cache
# Searching data for baseball_bat
# Found baseball_bat in cache
# Searching data for bicycle
# Found bicycle in cache
# Searching data for alarm_clock
# Found alarm_clock in cache
# Searching data for baseball_bat
# Found baseball_bat in cache
# Searching data for bicycle
# Found bicycle in cache
#    23/10000 [..............................] - ETA: 18:26 - loss: 0.8252 - categorical_accuracy: 0.7826Searching data for alarm_clock
# Found alarm_clock in cache
# Searching data for baseball_bat
# Found baseball_bat in cache
# Searching data for bicycle
# Found bicycle in cache
# Searching data for alarm_clock
# Found alarm_clock in cache
# Searching data for baseball_bat
# Found baseball_bat in cache
# Searching data for bicycle
# Found bicycle in cache
# Searching data for alarm_clock
# Found alarm_clock in cache
# Searching data for baseball_bat
# Found baseball_bat in cache
# Searching data for bicycle
# Found bicycle in cache
# Searching data for alarm_clock
# Found alarm_clock in cache
# Searching data for baseball_bat
# Found baseball_bat in cache
# Searching data for bicycle
# Found bicycle in cache
# Searching data for alarm_clock
# Found alarm_clock in cache
# Searching data for baseball_bat
# Found baseball_bat in cache
# Searching data for bicycle
# Found bicycle in cache
# Searching data for alarm_clock
# Found alarm_clock in cache
# Searching data for baseball_bat
# Found baseball_bat in cache
# Searching data for bicycle
# Found bicycle in cache
# Searching data for alarm_clock
# Found alarm_clock in cache
# Searching data for baseball_bat
# Found baseball_bat in cache
# Searching data for bicycle
# Found bicycle in cache
# Searching data for alarm_clock
# Found alarm_clock in cache
# Searching data for baseball_bat
# Found baseball_bat in cache
# Searching data for bicycle
# Found bicycle in cache
#    31/10000 [..............................] - ETA: 13:57 - loss: 0.6713 - categorical_accuracy: 0.8206Searching data for alarm_clock
# Found alarm_clock in cache
# Searching data for baseball_bat
# Found baseball_bat in cache
# Searching data for bicycle
# Found bicycle in cache
# Searching data for alarm_clock
# Found alarm_clock in cache
# Searching data for baseball_bat
# Found baseball_bat in cache
# Searching data for bicycle
# Found bicycle in cache
# Searching data for alarm_clock
# Found alarm_clock in cache
# Searching data for baseball_bat
# Found baseball_bat in cache
# Searching data for bicycle
# Found bicycle in cache
# Searching data for alarm_clock
# Found alarm_clock in cache
# Searching data for baseball_bat
# Found baseball_bat in cache
# Searching data for bicycle
# Found bicycle in cache
# Searching data for alarm_clock
# Found alarm_clock in cache
# Searching data for baseball_bat
# Found baseball_bat in cache
# Searching data for bicycle
# Found bicycle in cache
# Searching data for alarm_clock
# Found alarm_clock in cache
# Searching data for baseball_bat
# Found baseball_bat in cache
# Searching data for bicycle
# Found bicycle in cache
# Searching data for alarm_clock
# Found alarm_clock in cache
# Searching data for baseball_bat
# Found baseball_bat in cache
# Searching data for bicycle
# Found bicycle in cache
# Searching data for alarm_clock
# Found alarm_clock in cache
# Searching data for baseball_bat
# Found baseball_bat in cache
# Searching data for bicycle
# Found bicycle in cache
#